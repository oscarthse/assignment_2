# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/oscarthieleserrano/code/intro_to_ai/assignment_2/data/reservations.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79390 entries, 0 to 79389
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       79390 non-null  int64
#  1   month                      79390 non-null  object
#  2   status                     79390 non-null  object
#  3   status_date                79390 non-null  object
#  4   number                     79390 non-null  int64
#  5   day_of_month               79390 non-null  int64
#  6   reservation_days_advance   79390 non-null  int64
#  7   room_type                  79390 non-null  object
#  8   weekend_nights             79390 non-null  int64
#  9   week_nights                79390 non-null  int64
#  10  num_adults                 79390 non-null  int64
#  11  num_children               79386 non-null  float64
#  12  num_babies                 79390 non-null  int64
# ...

# %%
df.describe()
# Out:
#                year        number  day_of_month  reservation_days_advance  \
# count  79390.000000  79390.000000  79390.000000              79390.000000
# mean    2015.761784     30.334538     15.750661                107.863371
# std        0.509083     13.272608      8.786656                111.159098
# min     2015.000000      1.000000      1.000000                  0.000000
# 25%     2015.000000     20.000000      8.000000                 18.000000
# 50%     2016.000000     33.000000     16.000000                 70.000000
# 75%     2016.000000     41.000000     23.000000                168.000000
# max     2017.000000     53.000000     31.000000                737.000000
#
#        weekend_nights   week_nights    num_adults  num_children    num_babies  \
# count    79390.000000  79390.000000  79390.000000  79386.000000  79390.000000
# mean         0.906852      2.464227      1.849225      0.092094      0.008351
# ...

# %%
print(df.columns)
print(df.head())
print(df.tail())
print(df.sample(10))
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# Index(['year', 'month', 'status', 'status_date', 'number', 'day_of_month',
#        'reservation_days_advance', 'room_type', 'weekend_nights',
#        'week_nights', 'num_adults', 'num_children', 'num_babies', 'meal',
#        'name_hotel', 'CRM', 'returning', 'room_assigned',
#        'reservation_changes', 'deposit', 'operator', 'entreprise',
#        'waiting_list', 'segment', 'average_rate', 'num_vehicles',
#        'num_cancellations', 'num_bookings_not_canceled', 'special_requests',
#        'total_length_of_stay', 'total_spending'],
#       dtype='object')
#    year   month    status status_date  number  day_of_month  \
# 0  2015  August  Canceled  2014-10-17      33            13
# 1  2015    July  Canceled  2014-10-17      28             9
# 2  2015    July  Canceled  2014-10-17      28             9
# 3  2015    July  Canceled  2014-10-17      28             9
# 4  2015    July  Canceled  2014-10-17      28             9
#
# ...

# %%
df.isna().sum()
# Out:
# year                             0
# month                            0
# status                           0
# status_date                      0
# number                           0
# day_of_month                     0
# reservation_days_advance         0
# room_type                        0
# weekend_nights                   0
# week_nights                      0
# num_adults                       0
# num_children                     4
# num_babies                       0
# meal                             0
# name_hotel                       0
# CRM                              0
# returning                        0
# room_assigned                    0
# reservation_changes              0
# deposit                          0
# operator                     10610
# entreprise                   75044
# waiting_list                     0
# segment                          0
# average_rate                     0
# num_vehicles                     0
# num_cancellations                0
# ...

# %%
df.columns
# Out:
# Index(['year', 'month', 'status', 'status_date', 'number', 'day_of_month',
#        'reservation_days_advance', 'room_type', 'weekend_nights',
#        'week_nights', 'num_adults', 'num_children', 'num_babies', 'meal',
#        'name_hotel', 'CRM', 'returning', 'room_assigned',
#        'reservation_changes', 'deposit', 'operator', 'entreprise',
#        'waiting_list', 'segment', 'average_rate', 'num_vehicles',
#        'num_cancellations', 'num_bookings_not_canceled', 'special_requests',
#        'total_length_of_stay', 'total_spending'],
#       dtype='object')

# %%
len(df)
# Out:
# 79390

# %%
df["entreprise"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 79385    67.0
# 79386     NaN
# 79387     NaN
# 79388    67.0
# 79389     NaN
# Name: entreprise, Length: 79390, dtype: float64

# %%
df = df.drop(columns=["entreprise"])

# %%
df[["operator", ""]]
# Out:
#        year     month     status status_date  number  day_of_month  \
# 0      2015    August   Canceled  2014-10-17      33            13
# 1      2015      July   Canceled  2014-10-17      28             9
# 2      2015      July   Canceled  2014-10-17      28             9
# 3      2015      July   Canceled  2014-10-17      28             9
# 4      2015      July   Canceled  2014-10-17      28             9
# ...     ...       ...        ...         ...     ...           ...
# 79385  2017   January   Canceled  2016-12-07       2            14
# 79386  2016  December  Check-Out  2016-12-07      50             5
# 79387  2017     April   Canceled  2016-12-07      16            21
# 79388  2017   January   Canceled  2016-12-07       2            14
# 79389  2017      June   Canceled  2016-12-07      23             8
#
#        reservation_days_advance room_type  weekend_nights  week_nights  ...  \
# 0                           300         A               0            2  ...
# ...
